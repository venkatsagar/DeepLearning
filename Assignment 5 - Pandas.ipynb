# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import pandas as pd
dataset = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")
dataset
# Out:
#         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# 5       1880     Frank  0.027380   boy
# 6       1880    Joseph  0.022229   boy
# 7       1880    Thomas  0.021401   boy
# 8       1880     Henry  0.020641   boy
# 9       1880    Robert  0.020404   boy
# 10      1880    Edward  0.019965   boy
# 11      1880     Harry  0.018175   boy
# 12      1880    Walter  0.014822   boy
# 13      1880    Arthur  0.013504   boy
# 14      1880      Fred  0.013251   boy
# 15      1880    Albert  0.012609   boy
# 16      1880    Samuel  0.008648   boy
# 17      1880     David  0.007339   boy
# 18      1880     Louis  0.006993   boy
# 19      1880       Joe  0.006174   boy
# 20      1880   Charlie  0.006165   boy
# 21      1880  Clarence  0.006165   boy
# 22      1880   Richard  0.006148   boy
# ...

# %% [markdown]
# Questions

# %% [markdown]
# 1. Delete unnamed columns

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv', index_col=0)
dataset.head(10)
# Out:
#          name   percent  sex
# year
# 1880     John  0.081541  boy
# 1880  William  0.080511  boy
# 1880    James  0.050057  boy
# 1880  Charles  0.045167  boy
# 1880   George  0.043292  boy
# 1880    Frank  0.027380  boy
# 1880   Joseph  0.022229  boy
# 1880   Thomas  0.021401  boy
# 1880    Henry  0.020641  boy
# 1880   Robert  0.020404  boy

# %% [markdown]
# 2. Show the distribution of male and female

# %%
dataset.groupby(['sex']).count()
# Out:
#         name  percent
# sex
# boy   129000   129000
# girl  129000   129000

# %% [markdown]
# 3. Show the top 5 most preferred names

# %%
dataset['name'].value_counts()[0:6]
# Out:
# Jessie       258
# Leslie       247
# Guadalupe    244
# Jean         244
# Lee          240
# James        239
# Name: name, dtype: int64

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
N = dataset.groupby(['name']).median()
N.head()
# Out:
#           percent
# name
# Aaden    0.000442
# Aaliyah  0.001694
# Aarav    0.000101
# Aaron    0.000703
# Ab       0.000042

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
dataset.groupby(['sex','year']).count()
# Out:
#            name  percent
# sex  year
# boy  1880  1000     1000
#      1881  1000     1000
#      1882  1000     1000
#      1883  1000     1000
#      1884  1000     1000
#      1885  1000     1000
#      1886  1000     1000
#      1887  1000     1000
#      1888  1000     1000
#      1889  1000     1000
#      1890  1000     1000
#      1891  1000     1000
#      1892  1000     1000
#      1893  1000     1000
#      1894  1000     1000
#      1895  1000     1000
#      1896  1000     1000
#      1897  1000     1000
#      1898  1000     1000
#      1899  1000     1000
#      1900  1000     1000
#      1901  1000     1000
#      1902  1000     1000
#      1903  1000     1000
#      1904  1000     1000
#      1905  1000     1000
#      1906  1000     1000
#      1907  1000     1000
#      1908  1000     1000
#      1909  1000     1000
# ...         ...      ...
# girl 1979  1000     1000
#      1980  1000     1000
#      1981  1000     1000
#      1982  1000     1000
# ...

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import numpy as np

temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

import matplotlib.pyplot as plt
months = np.arange(12)
plt.plot(months, temp_max, 'go')
plt.plot(months, temp_min, 'co')
plt.xlabel('Month')
plt.ylabel('Min and max temperature')
# Out:
# Text(0, 0.5, 'Min and max temperature')

# %% [markdown]
# 1. Fitting it to the periodic function

# %%
from scipy import optimize
def yearly_temps(times, avg, ampl, time_offset):
    return (avg
            + ampl * np.cos((times + time_offset) * 1.8 * np.pi / times.max()))

res_max, cov_max = optimize.curve_fit(yearly_temps, months,
                                      temp_max, [40, 20, 0])
res_min, cov_min = optimize.curve_fit(yearly_temps, months,
                                      temp_min, [-40, 20, 0])

# %% [markdown]
# 2. Plot the Fit

# %%
days = np.linspace(0, 12, num=365)

plt.figure()
plt.plot(months, temp_max, 'go')
plt.plot(days, yearly_temps(days, *res_max), 'm-')
plt.plot(months, temp_min, 'co')
plt.plot(days, yearly_temps(days, *res_min), 'y-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')

plt.show()
